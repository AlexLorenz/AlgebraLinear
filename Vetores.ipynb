# %%
import numpy as np

# %%
v = np.array([1, 2, 3, 4])

# %%
v
# Out:
# array([1, 2, 3, 4])

# %%
type(v)
# Out:
# numpy.ndarray

# %%
# ?np.array

# %%
lista = [22, 5, 21, 7]

# %%
type(lista)
# Out:
# list

# %%
v1 = np.array(lista)

# %%
v1
# Out:
# array([22,  5, 21,  7])

# %%
type(v1)
# Out:
# numpy.ndarray

# %%
v2 = np.array([1,2,3,4,5])

# %%
v3 = np.array((1,2,3,4,5))

# %% [markdown]
# ## Representação Vetores

# %%
e1 = np.array([1, 0, 0])
e2 = np.array([0, 1, 1])
e3 = np.array([0, 0, 1])
