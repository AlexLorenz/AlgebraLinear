# %%
import numpy as np

# %%
u = np.array([2, 3])

# %%
v = np.array([4, -1])

# %%
u * v
# Out:
# array([8, 3])

# %%
u.dot(v)
# Out:
# 5

# %%
mod_u = np.linalg.norm(u)

# %%
mod_u
# Out:
# 3.605551275463989

# %%
np.linalg.norm(v)
# Out:
# 4.123105625617661
