# %%
import numpy as np

# %%
# Matriz
A = np.array([[2, -1],
              [0, 4]])

# %%
A
# Out:
# array([[ 2, -1],
#        [ 0,  4]])

# %%
B = np.array([[1, 0, -4],
              [4, -3, 2]])

# %%
B
# Out:
# array([[ 1,  0, -4],
#        [ 4, -3,  2]])

# %%
# Matriz segunda representação
F = np.matrix('1 2; 3 4')

# %%
# ?np.array

# %%
F.shape
# Out:
# (2, 2)

# %%
F
# Out:
# matrix([[1, 2],
#         [3, 4]])

# %%
D = np.matrix([[2, -1],[0, 4]])

# %%
D
# Out:
# matrix([[ 2, -1],
#         [ 0,  4]])

# %%
type(D)
# Out:
# numpy.matrix

# %%
#Matriz linha
L = np.array([3,4,5])

# %%
L
# Out:
# array([3, 4, 5])

# %%
L2 = np.array([[3,4,6]])

# %%
L.shape
# Out:
# (3,)

# %%
L2.shape
# Out:
# (1, 3)

# %%
#Matriz coluna
C1 = np.array([[1],[3],[7]])

# %%
C1
# Out:
# array([[1],
#        [3],
#        [7]])

# %%
C1.shape
# Out:
# (3, 1)

# %%
#Matriz nula
N = np.zeros([2,2])

# %%
# ?np.zeros

# %%
N
# Out:
# array([[0., 0.],
#        [0., 0.]])
